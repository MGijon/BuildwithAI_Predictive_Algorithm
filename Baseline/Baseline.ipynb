# %%
import json
import requests
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 

# %matplotlib inline

# %% [markdown]
# ## API CALLS

# %%
# ========================== #
# THE COVID TRACKING PROJECT #
# ========================== #

payload = {}
headers= {}

# (1) States Current
url = "https://covidtracking.com/api/states"
#response_current = requests.request("GET", url, headers=headers, data = payload)

# (2) States Daily
url = "https://covidtracking.com/api/states/daily"
#response_daily = requests.request("GET", url, headers=headers, data = payload)

# (3) US Current 
url = "http://covidtracking.com/api/us"
#response_US_Current = requests.request("GET", url, headers=headers, data = payload)

# (4) US Daily: FOR THIS BASELINE JUST SELECT THIS ONE
url = "https://covidtracking.com/api/us/daily"
response_US_Daily = requests.request("GET", url, headers=headers, data = payload)

json_data = json.loads(response_US_Daily.text)
US_daily = pd.DataFrame(json_data)

# %% [markdown]
# ## DATA ENGINEERING

# %%
# parse the date and lastModified fields
US_daily['date'] = pd.to_datetime(US_daily['date'], format='%Y%m%d')
US_daily['lastModified'] = [str(x)[:10] for x in US_daily['lastModified'].values]
US_daily['lastModified'] = pd.to_datetime(US_daily['lastModified'], format='%Y-%m-%d') # not necessary

US_daily.head(4)
# Out:
#         date  states  positive  negative  pending  hospitalizedCurrently  \
# 0 2020-07-23      56   4017735  44777235   3179.0                59846.0
# 1 2020-07-22      56   3946708  44074069   3051.0                59628.0
# 2 2020-07-21      56   3877558  43347717   3197.0                59316.0
# 3 2020-07-20      56   3813916  42661111   3003.0                58338.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                286329.0         10466.0          12933.0
# 1                283829.0         10457.0          12790.0
# 2                281581.0          6711.0          12629.0
# 3                279030.0          6558.0          12475.0
#
#    onVentilatorCurrently  ...  lastModified     total totalTestResults  \
# 0                 2472.0  ...    2020-07-23  48798149         48794970
# 1                 2440.0  ...    2020-07-22  48023828         48020777
# 2                 2414.0  ...    2020-07-21  47228472         47225275
# ...

# %%
#sns.plot(data=US_Daily[['date', 'positives', 'negatives']], palette="tab10", linewidth=2.5)

# %% [markdown]
# ## SPLIT SETS

# %%
#
