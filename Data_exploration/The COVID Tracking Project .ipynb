# %% [markdown]
# ## THE COVID TRACKING PROJECT
# ***

# %%
#!python -m pip install --upgrade pip
import json
import requests
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### States Current

# %%
url = "https://covidtracking.com/api/states"

payload = {}
headers= {}

response_current = requests.request("GET", url, headers=headers, data = payload)
#print(response_current.text.encode('utf8'))

json_data = json.loads(response_current.text)
df = pd.DataFrame(json_data)
df['date'] = pd.to_datetime(df['date'],format='%Y%m%d')
df.set_index('date',inplace=True)
df.head(4)
# Out:
#            state  positive  negative  pending  hospitalizedCurrently  \
# date
# 2020-07-23    AK      2684    186825      NaN                   36.0
# 2020-07-23    AL     74212    545315      NaN                 1547.0
# 2020-07-23    AR     36259    410221      NaN                  480.0
# 2020-07-23    AS         0      1037      NaN                    NaN
#
#             hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# date
# 2020-07-23                     NaN             NaN              NaN
# 2020-07-23                  8995.0             NaN           1043.0
# 2020-07-23                  2361.0             NaN              NaN
# 2020-07-23                     NaN             NaN              NaN
#
#             onVentilatorCurrently  onVentilatorCumulative  ...  posNeg  \
# date                                                       ...
# 2020-07-23                    1.0                     NaN  ...  189509
# 2020-07-23                    NaN                   553.0  ...  619527
# 2020-07-23                  107.0                   329.0  ...  446480
# 2020-07-23                    NaN                     NaN  ...    1037
#
#            deathIncrease hospitalizedIncrease  \
# date
# 2020-07-23             0                    0
# 2020-07-23            33                  457
# 2020-07-23             6                   44
# 2020-07-23             0                    0
#
#                                                 hash commercialScore  \
# date
# 2020-07-23  250b2f86b7f497e40057c76c9c34280febdd150b               0
# 2020-07-23  29d01db66f27c6d51adb56e6fe0e730c9efce112               0
# 2020-07-23  dbee50032803a8275442e649c5d7c1c659ea6d99               0
# 2020-07-23  3ef0986f4a9bd86467f99f1466dc940a8b200448               0
#
#             negativeRegularScore  negativeScore positiveScore  score  grade
# date
# 2020-07-23                     0              0             0      0
# 2020-07-23                     0              0             0      0
# 2020-07-23                     0              0             0      0
# 2020-07-23                     0              0             0      0
#
# [4 rows x 40 columns]

# %%
for col in df.columns:
    try:
        plt.figure(figsize=(10,5))
        sns.lineplot(x='date', y=col, hue='state', data=df.reset_index())

        plt.title(col)
    except:
        pass
# Out:
# Error in callback <function flush_figures at 0x7f5136e66e60> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2077                             print_method, dpi=dpi, orientation=orientation),
#    2078                         draw_disabled=True)
# -> 2079                     self.figure.draw(renderer)
#    2080                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2081                     bbox_inches = self.figure.get_tightbbox(renderer,
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2588                 artists.remove(spine)
#    2589
# -> 2590         self._update_title_position(renderer)
#    2591
#    2592         if not self.axison or inframe:
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2531                 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2532                         or ax.xaxis.get_label_position() == 'top'):
# -> 2533                     bb = ax.xaxis.get_tightbbox(renderer)
#    2534                 else:
#    2535                     bb = ax.get_window_extent(renderer)
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1200               if a.get_visible()),
#    1201             *ticklabelBoxes,
# -> 1202             *ticklabelBoxes2,
#    1203         ]
#    1204         bboxes = [b for b in bboxes
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/matplotlib/axis.py in <genexpr>(.0)
#    1198             *(a.get_window_extent(renderer)
#    1199               for a in [self.label, self.offsetText]
# -> 1200               if a.get_visible()),
#    1201             *ticklabelBoxes,
#    1202             *ticklabelBoxes2,
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     903             raise RuntimeError('Cannot get window extent w/o renderer')
#     904
# --> 905         bbox, info, descent = self._get_layout(self._renderer)
#     906         x, y = self.get_unitless_position()
#     907         x, y = self.get_transform().transform((x, y))
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     298             if clean_line:
#     299                 w, h, d = renderer.get_text_width_height_descent(
# --> 300                     clean_line, self._fontproperties, ismath=ismath)
#     301             else:
#     302                 w = h = d = 0
#
# ~/Documents/work/covid-un/venv/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     212         flags = get_hinting_flag()
#     213         font = self._get_agg_font(prop)
# --> 214         font.set_text(s, 0.0, flags=flags)
#     215         w, h = font.get_width_height()  # width and height of unrotated string
#     216         d = font.get_descent()
#
# KeyboardInterrupt:

# %% [markdown]
# ### States Daily

# %%
url = "https://covidtracking.com/api/states/daily"

payload = {}
headers= {}

response_daily = requests.request("GET", url, headers=headers, data = payload)
print(response_daily.text.encode('utf8'))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
json_data = json.loads(response_daily.text)
df = pd.DataFrame(json_data)
df['date'] = pd.to_datetime(df['date'],format='%Y%m%d')
df.set_index('date',inplace=True)
df.head(4)
# Out:
#            state  positive  negative  pending  hospitalizedCurrently  \
# date
# 2020-07-23    AK    2684.0  186825.0      NaN                   36.0
# 2020-07-23    AL   74212.0  545315.0      NaN                 1547.0
# 2020-07-23    AR   36259.0  410221.0      NaN                  480.0
# 2020-07-23    AS       0.0    1037.0      NaN                    NaN
#
#             hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# date
# 2020-07-23                     NaN             NaN              NaN
# 2020-07-23                  8995.0             NaN           1043.0
# 2020-07-23                  2361.0             NaN              NaN
# 2020-07-23                     NaN             NaN              NaN
#
#             onVentilatorCurrently  onVentilatorCumulative  ...  posNeg  \
# date                                                       ...
# 2020-07-23                    1.0                     NaN  ...  189509
# 2020-07-23                    NaN                   553.0  ...  619527
# 2020-07-23                  107.0                   329.0  ...  446480
# 2020-07-23                    NaN                     NaN  ...    1037
#
#            deathIncrease hospitalizedIncrease  \
# date
# 2020-07-23             0                    0
# 2020-07-23            33                  457
# 2020-07-23             6                   44
# 2020-07-23             0                    0
#
#                                                 hash commercialScore  \
# date
# 2020-07-23  250b2f86b7f497e40057c76c9c34280febdd150b               0
# 2020-07-23  29d01db66f27c6d51adb56e6fe0e730c9efce112               0
# 2020-07-23  dbee50032803a8275442e649c5d7c1c659ea6d99               0
# 2020-07-23  3ef0986f4a9bd86467f99f1466dc940a8b200448               0
#
#             negativeRegularScore  negativeScore positiveScore  score  grade
# date
# 2020-07-23                     0              0             0      0
# 2020-07-23                     0              0             0      0
# 2020-07-23                     0              0             0      0
# 2020-07-23                     0              0             0      0
#
# [4 rows x 40 columns]

# %%
df.sort_values('death',ascending=False)[['state','death']]['state'].unique()
# Out:
# array(['NY', 'NJ', 'MA', 'CA', 'IL', 'PA', 'MI', 'FL', 'TX', 'CT', 'LA',
#        'MD', 'GA', 'OH', 'AZ', 'IN', 'VA', 'NC', 'CO', 'MN', 'WA', 'MS',
#        'AL', 'SC', 'MO', 'RI', 'TN', 'WI', 'IA', 'NV', 'KY', 'NM', 'DC',
#        'DE', 'OK', 'NH', 'AR', 'NE', 'KS', 'OR', 'UT', 'PR', 'ID', 'SD',
#        'ME', 'WV', 'ND', 'VT', 'MT', 'WY', 'HI', 'AK', 'VI', 'GU', 'MP',
#        'AS'], dtype=object)

# %%
df.loc[df['state']=='NJ',['death']].plot()

# %%
for col in df.columns:
    try:
        plt.figure(figsize=(10,5))
        sns.lineplot(x='date', y=col, hue='state', data=df.reset_index())
        plt.title(col)
    except:
        pass

# %% [markdown]
# ### States info

# %%
url = "https://covidtracking.com/api/states/info"

payload = {}
headers= {}

response_info = requests.request("GET", url, headers=headers, data = payload)

#print(response_info.text.encode('utf8'))

# %%
json_data = json.loads(response_info.text)
df = pd.DataFrame(json_data)
df.head(4)
# Out:
#   state                                              notes  \
# 0    AK  Negatives = (Totals – Positives)\nPositives oc...
# 1    AL  Negatives = (Totals - Positives) \nPositives o...
# 2    AR                                               None
# 3    AS  AS does not have a regularly updated data sour...
#
#                                          covid19Site  \
# 0  http://dhss.alaska.gov/dph/Epi/id/Pages/COVID-...
# 1  https://alpublichealth.maps.arcgis.com/apps/op...
# 2  https://www.healthy.arkansas.gov/programs-serv...
# 3  https://www.americansamoa.gov/covid-19-advisories
#
#                                 covid19SiteSecondary  \
# 0  http://dhss.alaska.gov/dph/Epi/id/Pages/COVID-...
# 1            https://dph1.adph.state.al.us/covid-19/
# 2  https://adem.maps.arcgis.com/apps/opsdashboard...
# 3                 https://www.facebook.com/amsamgov/
#
#                                  covid19SiteTertiary          twitter  \
# 0  https://alaska-dhss.maps.arcgis.com/apps/opsda...     @Alaska_DHSS
# 1                                                     @alpublichealth
# 2                                                             @adhpio
# 3
#
#                                       covid19SiteOld            name fips pui  \
# 0  http://dhss.alaska.gov/dph/Epi/id/Pages/COVID-...          Alaska   02
# 1  http://www.alabamapublichealth.gov/infectiousd...         Alabama   01
# 2  https://www.healthy.arkansas.gov/programs-serv...        Arkansas   05
# 3  http://www.samoagovt.ws/2020/03/ministry-of-he...  American Samoa   60
#
#      pum
# 0  False
# 1  False
# 2  False
# 3  False

# %% [markdown]
# ### US Current

# %%
url = "http://covidtracking.com/api/us"

payload = {}
headers= {}

response_US_Current = requests.request("GET", url, headers=headers, data = payload)

#print(response.text.encode('utf8'))

# %%
json_data = json.loads(response_US_Current.text)
df = pd.DataFrame(json_data)
df.head(4)
# Out:
#        date  states  positive  negative  pending  hospitalizedCurrently  \
# 0  20200723      56   4017735  44777235     3179                  59846
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                  286329           10466            12933
#
#    onVentilatorCurrently  ...          lastModified     total  \
# 0                   2472  ...  2020-07-23T00:00:00Z  48798149
#
#   totalTestResults    posNeg  deathIncrease hospitalizedIncrease  \
# 0         48794970  48794970           1039                 2500
#
#    negativeIncrease  positiveIncrease  totalTestResultsIncrease  \
# 0            703166             71027                    774193
#
#                                        hash
# 0  47fbfb79cfdffb69204595f0de103f01166b7424
#
# [1 rows x 25 columns]

# %% [markdown]
# ### US Daily

# %%
url = "https://covidtracking.com/api/us/daily"

payload = {}
headers= {}

response_US_Daily = requests.request("GET", url, headers=headers, data = payload)

#print(response.text.encode('utf8'))

# %%
json_data = json.loads(response_US_Daily.text)
df = pd.DataFrame(json_data)
df.head(4)
# Out:
#        date  states  positive  negative  pending  hospitalizedCurrently  \
# 0  20200723      56   4017735  44777235   3179.0                59846.0
# 1  20200722      56   3946708  44074069   3051.0                59628.0
# 2  20200721      56   3877558  43347717   3197.0                59316.0
# 3  20200720      56   3813916  42661111   3003.0                58338.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                286329.0         10466.0          12933.0
# 1                283829.0         10457.0          12790.0
# 2                281581.0          6711.0          12629.0
# 3                279030.0          6558.0          12475.0
#
#    onVentilatorCurrently  ...          lastModified     total  \
# 0                 2472.0  ...  2020-07-23T00:00:00Z  48798149
# 1                 2440.0  ...  2020-07-22T00:00:00Z  48023828
# 2                 2414.0  ...  2020-07-21T00:00:00Z  47228472
# 3                 2403.0  ...  2020-07-20T00:00:00Z  46478030
#
#   totalTestResults    posNeg  deathIncrease hospitalizedIncrease  \
# 0         48794970  48794970           1039                 2500
# 1         48020777  48020777           1117                 2248
# 2         47225275  47225275           1038                 2551
# 3         46475027  46475027            362                 1647
#
#    negativeIncrease  positiveIncrease  totalTestResultsIncrease  \
# 0            703166             71027                    774193
# 1            726352             69150                    795502
# 2            686606             63642                    750248
# 3            654044             56971                    711015
#
#                                        hash
# 0  47fbfb79cfdffb69204595f0de103f01166b7424
# 1  1fb9827aa2d62689f16d74282dbefd9bb89e4a54
# 2  3540b85299a0876949457ef82d73f2d30f87ef58
# 3  4aeca501d8d04f10423adc9db2622d1dc9afd933
#
# [4 rows x 25 columns]
